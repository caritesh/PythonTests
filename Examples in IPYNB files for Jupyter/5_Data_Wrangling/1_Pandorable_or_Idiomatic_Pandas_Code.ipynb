# %% [markdown]
# ## Pandorable or Idiomatic Pandas Code
#
# Pandas have their own set of idioms. They are referred to as pandorable by the developers.

# %% [markdown]
# ## Step 1: Import the Required Library
#
# Let's talk about pandorable and idiomatic pandas code. We'll be looking at the indexing method, chaining memory optimizations, groupby and also plotting.
#
# - Import the pandas library:

# %%
import pandas as pd

# %% [markdown]
# ## Step 2: Load the Dataset
#
# - Load the __HousePrices.csv__ dataset using pandas:

# %%
df = pd.read_csv('../../Datasets/HousePrices.csv')

# %%
df.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %% [markdown]
# ## Step 3: Access Rows Using .iloc and .loc
#
# We can access individual rows using the **.iloc** method.
#
# Let's pass the index for it to give the output.
#
# - Access specific rows using .iloc:

# %%
df.iloc[0]
# Out:
# date              2014-05-02 00:00:00
# price                        313000.0
# bedrooms                          3.0
# bathrooms                         1.5
# sqft_living                      1340
# sqft_lot                         7912
# floors                            1.5
# waterfront                          0
# view                                0
# condition                           3
# sqft_above                       1340
# sqft_basement                       0
# yr_built                         1955
# yr_renovated                     2005
# street           18810 Densmore Ave N
# city                        Shoreline
# statezip                     WA 98133
# country                           USA
# Name: 0, dtype: object

# %% [markdown]
# **Observation**
#
# The first element in the DataFrame at the 0<sup>th</sup> index is shown as result.

# %% [markdown]
# Let's access the 11<sup>th</sup> element of the DataFrame using iloc.

# %%
df.iloc[10]
# Out:
# date             2014-05-02 00:00:00
# price                       463000.0
# bedrooms                         3.0
# bathrooms                       1.75
# sqft_living                     1710
# sqft_lot                        7320
# floors                           1.0
# waterfront                         0
# view                               0
# condition                          3
# sqft_above                      1710
# sqft_basement                      0
# yr_built                        1948
# yr_renovated                    1994
# street            Burke-Gilman Trail
# city                Lake Forest Park
# statezip                    WA 98155
# country                          USA
# Name: 10, dtype: object

# %% [markdown]
# We can do the same thing using the .loc method.

# %%
df.loc[0]
# Out:
# date              2014-05-02 00:00:00
# price                        313000.0
# bedrooms                          3.0
# bathrooms                         1.5
# sqft_living                      1340
# sqft_lot                         7912
# floors                            1.5
# waterfront                          0
# view                                0
# condition                           3
# sqft_above                       1340
# sqft_basement                       0
# yr_built                         1955
# yr_renovated                     2005
# street           18810 Densmore Ave N
# city                        Shoreline
# statezip                     WA 98133
# country                           USA
# Name: 0, dtype: object

# %%
df.loc[15]
# Out:
# date             2014-05-02 00:00:00
# price                       242500.0
# bedrooms                         3.0
# bathrooms                        1.5
# sqft_living                     1200
# sqft_lot                        9720
# floors                           1.0
# waterfront                         0
# view                               0
# condition                          4
# sqft_above                      1200
# sqft_basement                      0
# yr_built                        1965
# yr_renovated                       0
# street             14034 SE 201st St
# city                            Kent
# statezip                    WA 98042
# country                          USA
# Name: 15, dtype: object

# %% [markdown]
# ## Step 4: Check the DataFrame Size and Memory Usage
#
# Let's look at memory optimization. First, Let's see how much memory the DataFrame is consuming.

# %% [markdown]
# Let's see the individual splits of the columns by using memory_usage().

# %%
df.memory_usage()
# Out:
# Index              128
# date             36800
# price            36800
# bedrooms         36800
# bathrooms        36800
# sqft_living      36800
# sqft_lot         36800
# floors           36800
# waterfront       36800
# view             36800
# condition        36800
# sqft_above       36800
# sqft_basement    36800
# yr_built         36800
# yr_renovated     36800
# street           36800
# city             36800
# statezip         36800
# country          36800
# dtype: int64

# %% [markdown]
# **Observation**
#
# We can see the memory occupied by each column.

# %% [markdown]
# We can reduce the size of memory usage by manipulating certain columns, such as changing the datatypes of the columns.

# %%
df.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %% [markdown]
# **Observation**
#
# If we look at the head of the dataset, **bedrooms** cannot be in floating digits.

# %% [markdown]
# Let's convert that to integer.
#
# To convert the column values to integer, we can use astype('int32').

# %%
df['bedrooms'] = df['bedrooms'].astype('int32')

# %%
df.memory_usage()
# Out:
# Index              128
# date             36800
# price            36800
# bedrooms         18400
# bathrooms        36800
# sqft_living      36800
# sqft_lot         36800
# floors           36800
# waterfront       36800
# view             36800
# condition        36800
# sqft_above       36800
# sqft_basement    36800
# yr_built         36800
# yr_renovated     36800
# street           36800
# city             36800
# statezip         36800
# country          36800
# dtype: int64

# %% [markdown]
# __Observation__
#
# Now, we can see the memory space occupied by the column **bedroom** is lower.

# %% [markdown]
# ## Step 5: Groupby Operations
#
# One of the very important functions in pandas that lets you group by a certain field is the groupby method.
#
# Let's go ahead and group by City.
#
# Inside the groupby, we need to specify the column and the aggregation method.
# In this case, it will be mean.
#
#
# - Perform groupby operations on the DataFrame
#
# - Calculate the mean based on the **city** column

# %%
df.groupby(['city']).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\users\ajay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...

# %% [markdown]
# **Observation**
#
# Here, we can see the mean values of each city.

# %% [markdown]
# Now, let's find the maximum value in this city data.

# %%
df.groupby(['city']).max()
# Out:
#                                     date       price  bedrooms  bathrooms  \
# city
# Algona               2014-05-30 00:00:00    262000.0         4       3.00
# Auburn               2014-07-09 00:00:00    900000.0         7       5.25
# Beaux Arts Village   2014-05-28 00:00:00    745000.0         3       1.75
# Bellevue             2014-07-10 00:00:00   7062500.0         7       6.25
# Black Diamond        2014-07-08 00:00:00    650000.0         4       2.75
# Bothell              2014-07-09 00:00:00    749995.0         5       3.25
# Burien               2014-07-10 00:00:00   1035000.0         6       4.50
# Carnation            2014-07-10 00:00:00   1680000.0         4       4.25
# Clyde Hill           2014-07-02 00:00:00   3800000.0         5       5.50
# Covington            2014-07-10 00:00:00   2199900.0         5       3.00
# Des Moines           2014-07-09 00:00:00    950000.0         5       3.25
# Duvall               2014-07-08 00:00:00    955000.0         5       4.25
# ...

# %% [markdown]
# **Observation**
#
# Here, we can see the max values of each city.

# %% [markdown]
# ## Step 6: DateTime Operations
#
#
# Let's set an index. Here, we need to convert the **date** column into datetime values and set that as an index.
#
#
# - Convert the **date** column to datetime using pd.datetime()
# - Reassign this to df['date']

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# - Set the index of the DataFrame to the 'date' column using set_index()
#
# - Modify the same DataFrame by passing **inplace = True**

# %%
df.set_index(['date'],inplace = True)

# %% [markdown]
# Let's see the first few rows of the DataFrame.

# %%
df.head()
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-05-02   313000.0         3       1.50         1340      7912     1.5
# 2014-05-02  2384000.0         5       2.50         3650      9050     2.0
# 2014-05-02   342000.0         3       2.00         1930     11947     1.0
# 2014-05-02   420000.0         3       2.25         2000      8030     1.0
# 2014-05-02   550000.0         4       2.50         1940     10500     1.0
#
#             waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# date
# 2014-05-02           0     0          3        1340              0      1955
# 2014-05-02           0     4          5        3370            280      1921
# 2014-05-02           0     0          4        1930              0      1966
# 2014-05-02           0     0          4        1000           1000      1963
# 2014-05-02           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# **Observation**
#
# We can see the index is changed to datetime.

# %% [markdown]
# Before we plot date, time, values or time series, data can be resampled, which is a form of groupby using the resample() method.

# %% [markdown]
# Resample the DataFrame at different time intervals, and calculate the mean:

# %% [markdown]
# Since this is daily data, we can convert this into seven days.

# %%
df1 = df.drop(['street','city','statezip','country'], axis=1)

# %%
df1.resample('7D').mean().head(2)
# Out:
#                     price  bedrooms  bathrooms  sqft_living      sqft_lot  \
# date
# 2014-05-02  537825.723593  3.405276   2.140887  2096.707434  17072.395683
# 2014-05-09  540494.078704  3.467626   2.170863  2183.350120  15969.129496
#
#               floors  waterfront      view  condition   sqft_above  \
# date
# 2014-05-02  1.496403    0.002398  0.182254   3.434053  1775.916067
# 2014-05-09  1.485612    0.011990  0.196643   3.450839  1855.702638
#
#             sqft_basement     yr_built  yr_renovated
# date
# 2014-05-02     320.791367  1970.261391    836.558753
# 2014-05-09     327.647482  1971.666667    812.517986

# %%
df1.resample('M').mean().head(2)
# Out:
#                     price  bedrooms  bathrooms  sqft_living      sqft_lot  \
# date
# 2014-05-31  533822.837768  3.389706   2.139847  2114.912896  15959.428167
# 2014-06-30  547968.179909  3.404773   2.164640  2133.363469  14262.325379
#
#               floors  waterfront      view  condition   sqft_above  \
# date
# 2014-05-31  1.493495    0.005656  0.247738   3.436086  1797.126131
# 2014-06-30  1.513538    0.008720  0.241854   3.459844  1822.765489
#
#             sqft_basement     yr_built  yr_renovated
# date
# 2014-05-31     317.786765  1970.586538    826.834842
# 2014-06-30     310.597981  1970.746214    812.791189

# %%
df1.resample('Y').mean().head(2)
# Out:
#                     price  bedrooms  bathrooms  sqft_living      sqft_lot  \
# date
# 2014-12-31  551962.988473   3.40087   2.160815  2139.346957  14852.516087
#
#               floors  waterfront      view  condition   sqft_above  \
# date
# 2014-12-31  1.512065    0.007174  0.240652   3.451739  1827.265435
#
#             sqft_basement     yr_built  yr_renovated
# date
# 2014-12-31     312.081522  1970.786304    808.608261

# %% [markdown]
# ## Step 7: Plotting
#
# - Plot the DataFrame and the **price** column:

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# **Observation**
#
# It plots all the numerical variables.

# %% [markdown]
# Now, let's plot the price column of the DataFrame **df**

# %%
df['price'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## Step 8: Filter Data and Save to a New File
#
# Now, let's read the CSV file, filter the data by **city = "Seattle"** and store it into another CSV file using to_csv().
#
# - Filter the DataFrame for rows with the city __Seattle__, and save it to a new file

# %%
df = (pd.read_csv('../../Datasets/HousePrices.csv')
        .query('city == "Seattle"')
        .to_csv('Seattle.csv'))

# %% [markdown]
# Read the new CSV file into a pandas DataFrame:

# %%
df = pd.read_csv('Seattle.csv')

# %% [markdown]
# Let's print the DataFrame.

# %%
df.head(2)
# Out:
#    Unnamed: 0                 date      price  bedrooms  bathrooms  \
# 0           1  2014-05-02 00:00:00  2384000.0       5.0        2.5
# 1           5  2014-05-02 00:00:00   490000.0       2.0        1.0
#
#    sqft_living  sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         3650      9050     2.0           0     4          5        3370
# 1          880      6380     1.0           0     0          3         880
#
#    sqft_basement  yr_built  yr_renovated           street     city  statezip  \
# 0            280      1921             0  709 W Blaine St  Seattle  WA 98119
# 1              0      1938          1994   522 NE 88th St  Seattle  WA 98115
#
#   country
# 0     USA
# 1     USA
