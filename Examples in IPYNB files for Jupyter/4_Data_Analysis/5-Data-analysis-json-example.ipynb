# %%
#Import necessary libraries
import json
import pandas as pd
import numpy as np

# %%
#Reading data from s3
df = pd.read_json("https://raw.githubusercontent.com/ajaykuma/Datasets_For_Work/refs/heads/main/recipes.json",lines=True)

#creating a copy of df
Workdf = df.copy()

#Looking at columns
Workdf.columns
# Out:
# Index(['name', 'ingredients', 'url', 'image', 'cookTime', 'recipeYield',
#        'datePublished', 'prepTime', 'description'],
#       dtype='object')

# %%
Workdf.head(2)
# Out:
#                            name  \
# 0      Easter Leftover Sandwich
# 1  Pasta with Pesto Cream Sauce
#
#                                          ingredients  \
# 0  12 whole Hard Boiled Eggs\n1/2 cup Mayonnaise\...
# 1  3/4 cups Fresh Basil Leaves\n1/2 cup Grated Pa...
#
#                                                  url  \
# 0  http://thepioneerwoman.com/cooking/2013/04/eas...
# 1  http://thepioneerwoman.com/cooking/2011/06/pas...
#
#                                                image cookTime recipeYield  \
# 0  http://static.thepioneerwoman.com/cooking/file...       PT           8
# 1  http://static.thepioneerwoman.com/cooking/file...    PT10M           8
#
#   datePublished prepTime                                        description
# 0    2013-04-01    PT15M  Got leftover Easter eggs?    Got leftover East...
# 1    2011-06-06     PT6M  I finally have basil in my garden. Basil I can...

# %%
#Function to extract recipes that contain beef
def findingbeef(x:str):
    if 'beef' in x:
        return x
    elif 'Beef' in x:
        return x
    else:
        return 'not beef'

# %%
#extracting rows with recipes without beef
Workdf['ingredients'] = Workdf['ingredients'].apply(lambda n:findingbeef(n))
Workdf = Workdf[Workdf.ingredients != 'not beef'] 
Workdf.count()
# Out:
# name             47
# ingredients      47
# url              47
# image            47
# cookTime         47
# recipeYield      47
# datePublished    47
# prepTime         47
# description      47
# dtype: int64

# %%
#looking at unique values
Workdf['cookTime'].unique()
Workdf['prepTime'].unique()
# Out:
# array(['PT10M', 'PT20M', 'PT5M', 'PT15M', 'PT25M', 'PT1M', 'PT40M',
#        'PT30M', 'PT1H30M', 'PT45M', 'PT2H'], dtype=object)

# %%
#replacing 'PT' and '' values with PT0
#if there are missing values or no time duration (as it exists in the dataset)
#Workdf['cookTime'] = Workdf['cookTime'].replace(['PT',''],'PT0')
#Workdf['prepTime'] = Workdf['prepTime'].replace(['PT',''],'PT0')

#we dont need for our use case
Workdf['prepTime'] = Workdf['prepTime'].apply(lambda n:n[2:])
Workdf['cookTime'] = Workdf['cookTime'].apply(lambda n:n[2:])

# %%
#Workdf['prepTime']
Workdf[['cookTime','prepTime']].head(10)
# Out:
#     cookTime prepTime
# 7        25M      10M
# 25        3H      20M
# 27       25M       5M
# 36       20M      10M
# 68        4H       5M
# 70       25M      20M
# 71        1H      20M
# 74       10M       5M
# 77       15M       5M
# 104       3H      10M

# %%
#using timedelta to convert 
def timeff(x):
    if x[1] == 'H':
        x = x[0]+x[1].replace('H','h')
    elif x[1] == 'M':
        x = x[0]+x[1].replace('S','s')
    elif x[1] == 'S':
        x = x[0]+x[1].replace('S','s')
    return x
    n = pd.Timedelta(x)
    return n

# %%
#pd.Timedelta('1min')
#Workdf['cookTime'][7].apply(lambda n:timeff(pd.Timedelta(n)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 2
#       1 #pd.Timedelta('1min')
# ----> 2 Workdf['cookTime'][7].apply(lambda n:timeff(pd.Timedelta(n)))
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
#before applying fucntion,confirming datatypes
Workdf.dtypes
# Out:
# name             object
# ingredients      object
# url              object
# image            object
# cookTime         object
# recipeYield      object
# datePublished    object
# prepTime         object
# description      object
# dtype: object

# %%
Workdf[['name','prepTime','cookTime']]
# Out:
#                                                   name prepTime cookTime
# 7                                          Patty Melts      10M      25M
# 25         Spicy Stewed Beef with Creamy Cheddar Grits      20M       3h
# 27                     Pork Chops with Garlic and Wine     5min      25M
# 36          Salisbury Steak, Mashed Potatoes, and Peas      10M      20M
# 68                   Hot &amp; Spicy Italian Drip Beef     5min       4h
# 70                         Surf &amp; Turf Cajun Pasta      20M      25M
# 71                                     Spaghetti Sauce      20M       1h
# 74                             Pepperoni Pizza Burgers     5min      10M
# 77                               Supreme Pizza Burgers     5min      15M
# 104                     Short Ribs with Wine and Cream      10M       3h
# 117                  Pork Roast with Apples and Onions      15M       2h
# 133                          Spicy Whiskey BBQ Sliders      15M      15M
# 137                           Beef Stew with Mushrooms      25M      30M
# 138                    Beef Stew with Beer and Paprika      10M       2h
# 140                             Beef and Bean Burritos     5min      11M
# 143                              BBQ Comfort Meatballs      15M      45M
# 148               Meatballs with Peppers and Pineapple      20M      20M
# 167                         Short Ribs in Tomato Sauce      10M       4h
# 192                                  Italian Pot Roast     1min       4h
# 199                                     Cajun Meatloaf      40M      40M
# 205                                 Braised Short Ribs      20M       2h
# 206                               Braised Beef Brisket      10M       6h
# 220    Mushroom-and-Swiss Sliders with Spicy Fry Sauce      15M      30M
# 233                               My Favorite Meatloaf      15M      45M
# 234                                 Burgundy Mushrooms     5min       9h
# 256                French Onion Soup Stuffed Mushrooms      20M      30M
# 265                                         Baked Ziti      15M      45M
# 274                                  Sunday Night Stew      15M       3h
# 279                              Italian Meatball Soup      30M      45M
# 284                                Drip Beef, Two Ways     5min       6h
# 286                          Spaghetti &amp; Meatballs      25M       1h
# 297                                   Passover Brisket      10M       7h
# 301                                        Sloppy Joes      10M      20M
# 379                                      Cowboy Nachos      15M     5min
# 397                                         Enchiladas       1h      20M
# 419                                        Steak Bites     5min      10M
# 422                                 My Favorite Burger      20M     6min
# 431                                  French Onion Soup      20M       2h
# 436                            Pasta alla Marlboro Man      10M       1h
# 450                             Ryan’s Bolognese Sauce      30M       2h
# 452                          Leftover Brisket Tostadas      15M     5min
# 464  Cooking With Pastor Ryan: Delicious Mexican La...      45M      35M
# 501                                        Salad Tacos      10M      15M
# 510                                       Beef Fajitas       2h      15M
# 514                            The Best Lasagna. Ever.      30M      30M
# 519                            Roasted Beef Tenderloin      25M      25M
# 533                          Hot Roast Beef Sandwiches      20M      20M

# %%
#applying function
Workdf['cookTime'] = Workdf['cookTime'].apply(lambda n:timeff(n))
Workdf['prepTime'] = Workdf['prepTime'].apply(lambda n:timeff(n))

# %%
Workdf[['name','prepTime','cookTime']].head(5)
# Out:
#                                            name prepTime cookTime
# 7                                   Patty Melts      10M      25M
# 25  Spicy Stewed Beef with Creamy Cheddar Grits      20M       3h
# 27              Pork Chops with Garlic and Wine       5M      25M
# 36   Salisbury Steak, Mashed Potatoes, and Peas      10M      20M
# 68            Hot &amp; Spicy Italian Drip Beef       5M       4h

# %%
type(Workdf['prepTime'][7])
# Out:
# str

# %%
#to be checked
#converting values in cookTime n PrepTime into minutes
#Workdf['cookTime'] = Workdf['cookTime']/np.timedelta64(1, 'm')
#Workdf['prepTime'] = Workdf['prepTime']/np.timedelta64(1, 'm')

# %%
#function to assess difficulty level
def difflvl(x):
    if x<30:
        return 'easy'
    elif x>=30 and x<=60:
        return 'medium'
    else:
        return 'hard'

# %%
#computing total cook time and applying function
Workdf['cookTimeTot'] = Workdf['cookTime']+Workdf['prepTime']
Workdf['difficulty'] = Workdf['cookTimeTot'].apply(lambda n:difflvl(n))
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_8256\1328425785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Workdf['cookTimeTot'] = Workdf['cookTime']+Workdf['prepTime']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 #computing total cook time and applying function
#       2 Workdf['cookTimeTot'] = Workdf['cookTime']+Workdf['prepTime']
# ----> 3 Workdf['difficulty'] = Workdf['cookTimeTot'].apply(lambda n:difflvl(n))
#
# File c:\users\ajay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\users\ajay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\users\ajay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\users\ajay\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[16], line 3, in <lambda>(n)
#       1 #computing total cook time and applying function
#       2 Workdf['cookTimeTot'] = Workdf['cookTime']+Workdf['prepTime']
# ----> 3 Workdf['difficulty'] = Workdf['cookTimeTot'].apply(lambda n:difflvl(n))
#
# Cell In[15], line 3, in difflvl(x)
#       2 def difflvl(x):
# ----> 3     if x<30:
#       4         return 'easy'
#       5     elif x>=30 and x<=60:
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
#Groupby and fining avg cookTime for each level of difficulty
Result = Workdf.groupby(['difficulty']).agg({'cookTime':['mean']})
Result.columns = Result.columns.get_level_values(1)
Result = Result.reset_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Result['difficulty'] = Result['difflvl']
Result['avg_total_cooking_time'] = Result['mean']
#Result.drop(['mean','difflvl'],axis=1,inplace=True)
Result.drop(['mean'],axis=1,inplace=True)
#Result.to_csv('report.csv',index=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>difficulty</th>
#       <th>avg_total_cooking_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>easy</td>
#       <td>9.625000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>hard</td>
#       <td>169.782609</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>medium</td>
#       <td>28.125000</td>
#     </tr>
#   </tbody>
# </table>
# </div>
